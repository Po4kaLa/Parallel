# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
plt.plot([2, 4, 7, 8, 16, 20, 40], [2, 4, 7, 8, 16, 20, 40])
plt.plot([2, 4, 7, 8, 16, 20, 40], [1.94, 3.77, 6.42, 7.33, 12.94, 15.38, 22.78])
plt.plot([2, 4, 7, 8, 16, 20, 40], [1.91, 2.92, 5.41, 7.34, 14.16, 13.01, 25.93])
plt.plot([2, 4, 7, 8, 16, 20, 40], [1.91, 2.92, 5.41, 7.34, 14.16, 13.01, 25.93])

plt.legend(['linear', '20 000', '40 000'])
plt.xlabel("Кол-во потоков (p)")
plt.ylabel("Ускорение (Sp)")
# Out:
# Text(0, 0.5, 'Ускорение (Sp)')

# %%
plt.plot([2, 4, 7, 8, 16, 20, 40], [2, 4, 7, 8, 16, 20, 40])
plt.plot([2, 4, 7, 8, 16, 20, 40], [1.79, 3.30, 5.28, 5.89, 9.39, 10.75, 12.41])

plt.legend(['linear', 'Local var'])
plt.xlabel("Кол-во потоков (p)")
plt.ylabel("Ускорение (Sp)")
# Out:
# Text(0, 0.5, 'Ускорение (Sp)')
